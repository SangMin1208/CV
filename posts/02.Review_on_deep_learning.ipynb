# %% [raw]
# ---
# title: "02. Review on Deep Learning"
# author: "이상민"
# date: "01/21/2026"
# ---

# %% [markdown]
# ## 1. Deep vs. Machine learning

# %% [markdown]
# ### A. Shallow learning vs. Deep learning
#
# `-` Shallow learning
#
# * only has one layer
# * feature : vector
#
# `-` Deep learning
#
# * has more than one layer
#
#
# <img src = "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRQ_SDQDfs2gMEKFqQW04yPLpYk_su773dUzQ&s" width = 500, height = 300>
#
# imput image(224 x 224 x 3) : width x height x channel

# %% [markdown]
# <img src = "../assets/0.png" width = 500, height = 300>
